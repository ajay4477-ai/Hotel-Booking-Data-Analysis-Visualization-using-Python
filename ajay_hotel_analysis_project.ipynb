# %%
# 1. Data Import and Data Exploration

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("datasets/fact_bookings.csv")

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.room_category.value_counts()
# Out:
# room_category
# RT2    49505
# RT1    38446
# RT3    30566
# RT4    16073
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar", title = "Booking Platform")
# Out:
# <Axes: title={'center': 'Booking Platform'}, xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date = pd.read_csv("datasets/dim_date.csv")
df_date.shape
# Out:
# (92, 4)

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_hotels = pd.read_csv("datasets/dim_hotels.csv")
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_rooms = pd.read_csv("datasets/dim_rooms.csv")
df_rooms.shape
# Out:
# (4, 2)

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_agg_bookings = pd.read_csv("datasets/fact_aggregated_bookings.csv")
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind="bar", title = "City Wise Hotels")
# Out:
# <Axes: title={'center': 'City Wise Hotels'}, xlabel='city'>

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
# Exercise-1. Find out unique property ids in aggregate bookings dataset
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
# Exercise-2. Find out total bookings per property_id
df_agg_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
# Exercise-3. Find out days on which bookings are greater than capacity
df_agg_bookings[df_agg_bookings.successful_bookings > df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
# Exercise-4. Find out properties that have highest capacity
df_agg_bookings.capacity.max()
# Out:
# np.float64(50.0)

# %%
df_agg_bookings[df_agg_bookings.capacity == df_agg_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %%
# 2. Data Cleaning

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests <= 0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.no_guests >= 0]

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
# (2) Outlier removal in revenue generated
df_bookings.revenue_generated.min()
# Out:
# np.int64(6500)

# %%
df_bookings.revenue_generated.max()
# Out:
# np.int64(28560000)

# %%
df_bookings.revenue_generated.mean()
# Out:
# np.float64(15378.036937686695)

# %%
df_bookings.revenue_generated.median()
# Out:
# np.float64(13500.0)

# %%
avg = df_bookings.revenue_generated.mean()
avg
# Out:
# np.float64(15378.036937686695)

# %%
std = df_bookings.revenue_generated.std()
std
# Out:
# np.float64(93040.1549314641)

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limite = avg - 3*std
lower_limite
# Out:
# np.float64(-263742.4278567056)

# %%
df_bookings[df_bookings.revenue_generated <= 0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings[df_bookings.revenue_generated <= higher_limit]
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134578.000000
# mean      12696.011822
# std        6927.841641
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# np.float64(33479.53674501214)

# %%
df_bookings[df_bookings.revenue_realized > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
# One observation we can have in above dataframe is that all rooms are RT4 which means presidential suit. Now since RT4 is a luxurious room it is likely their rent will 
# be higher. To make a fair analysis, we need to do data analysis only on RT4 room types

df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings[df_bookings.room_category == "RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
# mean + 3*standard deviation
23439 + 3*9048
# Out:
# 50583

# %%
# Here higher limit comes to be 50583 and in our dataframe above we can see that max value for revenue realized is 45220. 
# Hence we can conclude that there is no outlier and we don't need to do any data cleaning on this particular column.

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77899
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
# Total values in our dataframe is 134576. Out of that 77899 rows has null rating. Since there are many rows with null rating, we should not filter these values. 
# Also we should not replace this rating with a median or mean rating etc.

# %%
# Exercise-1. In aggregate bookings find columns that have null values. Fill these null values with whatever you think 
# is the appropriate subtitute (possible ways is to use mean or median)
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
mean_of_capacity = df_agg_bookings.capacity.mean()
mean_of_capacity
# Out:
# np.float64(25.280495759947815)

# %%
df_agg_bookings.fillna(df_agg_bookings.capacity.mean(), inplace=True)

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %%
# Exercise-2. In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those records
df_agg_bookings[df_agg_bookings.successful_bookings > df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings = df_agg_bookings[df_agg_bookings.successful_bookings <= df_agg_bookings.capacity]
df_agg_bookings.shape
# Out:
# (9194, 5)

# %%
# 3. Data Transformation
# Create occupancy percentage column
df_agg_bookings["occ_per"] = (df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"])*100
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 4           16558      1-May-22           RT1                   18      19.0
# 5           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#         occ_per
# 0     83.333333
# ...

# %%
df_agg_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9194 entries, 0 to 9199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9194 non-null   int64
#  1   check_in_date        9194 non-null   object
#  2   room_category        9194 non-null   object
#  3   successful_bookings  9194 non-null   int64
#  4   capacity             9194 non-null   float64
#  5   occ_per              9194 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 502.8+ KB

# %%
# 4. Insights Generation
# 1. What is an average occupancy rate in each of the room categories?
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#      occ_per
# 0  83.333333
# 1  93.333333
# 2  76.666667

# %%
df_agg_bookings.groupby("room_category")["occ_per"].mean()
# Out:
# room_category
# RT1    57.888951
# RT2    58.009714
# RT3    58.028291
# RT4    59.277625
# Name: occ_per, dtype: float64

# %%
# I don't understand RT1, RT2 etc. Print room categories such as Standard, Premium, Elite etc along with average occupancy percentage
df = pd.merge(df_agg_bookings, df_rooms, left_on="room_category", right_on="room_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#      occ_per room_id room_class
# 0  83.333333     RT1   Standard
# 1  93.333333     RT1   Standard
# 2  76.666667     RT1   Standard
# 3  94.736842     RT1   Standard
# 4  70.000000     RT1   Standard

# %%
df.drop("room_id", axis=1, inplace=True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#      occ_per room_class
# 0  83.333333   Standard
# 1  93.333333   Standard
# 2  76.666667   Standard
# 3  94.736842   Standard
# 4  70.000000   Standard

# %%
df.groupby("room_class")["occ_per"].mean()
# Out:
# room_class
# Elite           58.009714
# Premium         58.028291
# Presidential    59.277625
# Standard        57.888951
# Name: occ_per, dtype: float64

# %%
# 2. Print average occupancy rate per city
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df, df_hotels, on = "property_id")

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#      occ_per room_class  property_name  category       city
# 0  83.333333   Standard  Atliq Exotica    Luxury     Mumbai
# 1  93.333333   Standard      Atliq Bay    Luxury  Bangalore
# 2  76.666667   Standard   Atliq Palace  Business  Bangalore
# 3  94.736842   Standard   Atliq Grands    Luxury      Delhi
# 4  70.000000   Standard     Atliq City  Business     Mumbai

# %%
df.groupby("city")["occ_per"].mean()
# Out:
# city
# Bangalore    56.332232
# Delhi        61.507137
# Hyderabad    58.120465
# Mumbai       57.908810
# Name: occ_per, dtype: float64

# %%
# 3. When was the occupancy better? Weekday or Weekend?
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#      occ_per
# 0  83.333333
# 1  93.333333
# 2  76.666667
# 4  94.736842
# 5  70.000000

# %%
df = pd.merge(df_date, df_agg_bookings, left_on="date", right_on="check_in_date")
df.head()
# Out:
#         date  mmm yy week no  day_type  property_id check_in_date  \
# 0  10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 1  10-May-22  May 22    W 20  weekeday        18560     10-May-22
# 2  10-May-22  May 22    W 20  weekeday        19562     10-May-22
# 3  10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 4  10-May-22  May 22    W 20  weekeday        17558     10-May-22
#
#   room_category  successful_bookings  capacity    occ_per
# 0           RT3                   15      29.0  51.724138
# 1           RT1                   19      30.0  63.333333
# 2           RT1                   18      30.0  60.000000
# 3           RT1                   16      30.0  53.333333
# 4           RT1                   11      19.0  57.894737

# %%
df.groupby("day_type")["occ_per"].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: occ_per, dtype: float64

# %%
# from the above we can say that occupancy is batter on the weekend with 72 percent

# %%
# 4: In the month of June, what is the occupancy for different cities
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df, df_hotels, on="property_id")
df.head()
# Out:
#         date  mmm yy week no  day_type  property_id check_in_date  \
# 0  10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 1  10-May-22  May 22    W 20  weekeday        18560     10-May-22
# 2  10-May-22  May 22    W 20  weekeday        19562     10-May-22
# 3  10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 4  10-May-22  May 22    W 20  weekeday        17558     10-May-22
#
#   room_category  successful_bookings  capacity    occ_per property_name  \
# 0           RT3                   15      29.0  51.724138  Atliq Palace
# 1           RT1                   19      30.0  63.333333    Atliq City
# 2           RT1                   18      30.0  60.000000     Atliq Bay
# 3           RT1                   16      30.0  53.333333  Atliq Palace
# 4           RT1                   11      19.0  57.894737  Atliq Grands
#
#    category       city
# 0  Business  Bangalore
# 1  Business  Hyderabad
# 2    Luxury  Bangalore
# 3  Business  Bangalore
# ...

# %%
june_22 = df[df["mmm yy"] == "Jun 22"]
june_22.head()
# Out:
#            date  mmm yy week no  day_type  property_id check_in_date  \
# 2200  10-Jun-22  Jun 22    W 24  weekeday        16559     10-Jun-22
# 2201  10-Jun-22  Jun 22    W 24  weekeday        19562     10-Jun-22
# 2202  10-Jun-22  Jun 22    W 24  weekeday        19563     10-Jun-22
# 2203  10-Jun-22  Jun 22    W 24  weekeday        17558     10-Jun-22
# 2204  10-Jun-22  Jun 22    W 24  weekeday        16558     10-Jun-22
#
#      room_category  successful_bookings  capacity    occ_per  property_name  \
# 2200           RT1                   20      30.0  66.666667  Atliq Exotica
# 2201           RT1                   19      30.0  63.333333      Atliq Bay
# 2202           RT1                   17      30.0  56.666667   Atliq Palace
# 2203           RT1                    9      19.0  47.368421   Atliq Grands
# 2204           RT1                   11      19.0  57.894737   Atliq Grands
#
#       category       city
# 2200    Luxury     Mumbai
# 2201    Luxury  Bangalore
# ...

# %%
june_22.groupby("city")["occ_per"].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.44
# Name: occ_per, dtype: float64

# %%
june_22.groupby("city")["occ_per"].mean().round(2).sort_values(ascending=False).plot(kind="bar", title="Occupancy Rate by City")
# Out:
# <Axes: title={'center': 'Occupancy Rate by City'}, xlabel='city'>

# %%
# 5: We got new data for the month of august. Append that to existing data
df_august = pd.read_csv("datasets/new_data_august.csv")
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df.head()
# Out:
#         date  mmm yy week no  day_type  property_id check_in_date  \
# 0  10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 1  10-May-22  May 22    W 20  weekeday        18560     10-May-22
# 2  10-May-22  May 22    W 20  weekeday        19562     10-May-22
# 3  10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 4  10-May-22  May 22    W 20  weekeday        17558     10-May-22
#
#   room_category  successful_bookings  capacity    occ_per property_name  \
# 0           RT3                   15      29.0  51.724138  Atliq Palace
# 1           RT1                   19      30.0  63.333333    Atliq City
# 2           RT1                   18      30.0  60.000000     Atliq Bay
# 3           RT1                   16      30.0  53.333333  Atliq Palace
# 4           RT1                   11      19.0  57.894737  Atliq Grands
#
#    category       city
# 0  Business  Bangalore
# 1  Business  Hyderabad
# 2    Luxury  Bangalore
# 3  Business  Bangalore
# ...

# %%
latest_df = pd.concat([df, df_august], ignore_index=True, axis=0)
latest_df.tail(10)
# Out:
#            date  mmm yy week no  day_type  property_id check_in_date  \
# 6494  31-Jul-22  Jul 22    W 32   weekend        17558     31-Jul-22
# 6495  31-Jul-22  Jul 22    W 32   weekend        19563     31-Jul-22
# 6496  31-Jul-22  Jul 22    W 32   weekend        17561     31-Jul-22
# 6497        NaN  Aug-22    W 32  weekeday        16559     01-Aug-22
# 6498        NaN  Aug-22    W 32  weekeday        19562     01-Aug-22
# 6499        NaN  Aug-22    W 32  weekeday        19563     01-Aug-22
# 6500        NaN  Aug-22    W 32  weekeday        19558     01-Aug-22
# 6501        NaN  Aug-22    W 32  weekeday        19560     01-Aug-22
# 6502        NaN  Aug-22    W 32  weekeday        17561     01-Aug-22
# 6503        NaN  Aug-22    W 32  weekeday        17564     01-Aug-22
#
#      room_category  successful_bookings  capacity  occ_per  property_name  \
# 6494           RT4                    3       6.0     50.0   Atliq Grands
# ...

# %%
latest_df.shape
# Out:
# (6504, 15)

# %%
# 6. Print revenue realized per city
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df_bookings, df_hotels, on="property_id")

# %%
df.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 2  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 3  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 4  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294438788
# Hyderabad    325179310
# Mumbai       668602231
# Name: revenue_realized, dtype: int64
